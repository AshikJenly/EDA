# %%
import pandas as pd

# %%
df = pd.read_csv("./Autom/Automobile_data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.groupby('body-style').groups.keys()
# Out:
# dict_keys(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'])

# %%
style = df.groupby('body-style')

# %%
style.get_group('convertible')
# style.get_group('sedan')
# Out:
#      symboling normalized-losses           make fuel-type aspiration
# 0            3                 ?    alfa-romero       gas        std  \
# 1            3                 ?    alfa-romero       gas        std
# 72           3               142  mercedes-benz       gas        std
# 128          3                 ?        porsche       gas        std
# 172          2               134         toyota       gas        std
# 189          3                 ?     volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# 1            two  convertible          rwd           front        88.6  ...
# 72           two  convertible          rwd           front        96.6  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 172          two  convertible          rwd           front        98.4  ...
# ...

# %%
double_grouping = df.groupby(["body-style","drive-wheels"])
double_grouping

# %%
double_grouping.first()
# Out:
#                           symboling normalized-losses           make
# body-style  drive-wheels
# convertible fwd                   3                 ?     volkswagen  \
#             rwd                   3                 ?    alfa-romero
# hardtop     fwd                   2               168         nissan
#             rwd                   0                93  mercedes-benz
# hatchback   4wd                   0                 ?           audi
#             fwd                   2               121      chevrolet
#             rwd                   1                 ?    alfa-romero
# sedan       4wd                   2               164           audi
#             fwd                   2               164           audi
#             rwd                   2               192            bmw
# wagon       4wd                   0                85         subaru
#             fwd                   1                 ?           audi
# ...

# %%
style['normalized-losses'].min()
# Out:
# body-style
# convertible    134
# hardtop        134
# hatchback      101
# sedan          102
# wagon          103
# Name: normalized-losses, dtype: object

# %%
style['normalized-losses'].max()
# Out:
# body-style
# convertible    ?
# hardtop        ?
# hatchback      ?
# sedan          ?
# wagon          ?
# Name: normalized-losses, dtype: object

# %%
style.get_group('convertible')['symboling'].mean()
# Out:
# 2.8333333333333335

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
new_dataset=df.filter(['length','width','height','price'],axis=1)

# %%
new_dataset
# Out:
#      length  width  height  price
# 0     168.8   64.1    48.8  13495
# 1     168.8   64.1    48.8  16500
# 2     171.2   65.5    52.4  16500
# 3     176.6   66.2    54.3  13950
# 4     176.6   66.4    54.3  17450
# ..      ...    ...     ...    ...
# 200   188.8   68.9    55.5  16845
# 201   188.8   68.8    55.5  19045
# 202   188.8   68.9    55.5  21485
# 203   188.8   68.9    55.5  22470
# 204   188.8   68.9    55.5  22625
#
# [205 rows x 4 columns]

# %%
new_dataset=new_dataset.fillna(0)

# %%
new_dataset=new_dataset.drop('price',axis=1)

# %%
new_dataset.agg('mean',axis=0)
# Out:
# length    174.049268
# width      65.907805
# height     53.724878
# dtype: float64

# %%
new_dataset.agg(['mean',np.sum],axis=0)
# Out:
#             length         width        height
# mean    174.049268     65.907805     53.724878
# sum   35680.100000  13511.100000  11013.600000

# %%
new_dataset.agg(['mean','sum'],axis=0)
# Out:
#             length         width        height
# mean    174.049268     65.907805     53.724878
# sum   35680.100000  13511.100000  11013.600000

# %%
df.groupby(['drive-wheels','body-style']).agg({'height':min,'length':max})
# Out:
#                           height  length
# drive-wheels body-style
# 4wd          hatchback      52.0   178.2
#              sedan          54.3   176.6
#              wagon          54.9   173.6
# fwd          convertible    55.6   159.3
#              hardtop        53.3   162.4
#              hatchback      49.4   186.6
#              sedan          50.6   192.7
#              wagon          53.0   192.7
# rwd          convertible    48.8   180.3
#              hardtop        51.6   199.2
#              hatchback      49.6   183.5
#              sedan          47.8   208.1
#              wagon          54.1   198.9

# %%
df.groupby(['drive-wheels']).agg({'height':min,'length':max})
# Out:
#               height  length
# drive-wheels
# 4wd             52.0   178.2
# fwd             49.4   192.7
# rwd             47.8   208.1

# %%
df.groupby(["body-style","drive-wheels"]).agg(max_price=('price', max),min_price=('price', min))
# Out:
#                          max_price min_price
# body-style  drive-wheels
# convertible fwd              11595     11595
#             rwd              37028     13495
# hardtop     fwd               8249      8249
#             rwd               9639     11199
# hatchback   4wd                  ?      7603
#             fwd               9988     10595
#             rwd                  ?     10945
# sedan       4wd               9233     11259
#             fwd                  ?     10245
#             rwd               9298     11900
# wagon       4wd               8778     11694
#             fwd               9295     10198
#             rwd              28248     12440

# %%
pd.crosstab(df["make"], df["body-style"])
# Out:
# body-style     convertible  hardtop  hatchback  sedan  wagon
# make
# alfa-romero              2        0          1      0      0
# audi                     0        0          1      5      1
# bmw                      0        0          0      8      0
# chevrolet                0        0          2      1      0
# dodge                    0        0          5      3      1
# honda                    0        0          7      5      1
# isuzu                    0        0          1      3      0
# jaguar                   0        0          0      3      0
# mazda                    0        0         10      7      0
# mercedes-benz            1        2          0      4      1
# mercury                  0        0          1      0      0
# mitsubishi               0        0          9      4      0
# nissan                   0        1          5      9      3
# peugot                   0        0          0      7      4
# ...

# %%
pd.crosstab(df["make"], df["body-style"],margins=True,margins_name="Total Made")
# Out:
# body-style     convertible  hardtop  hatchback  sedan  wagon  Total Made
# make
# alfa-romero              2        0          1      0      0           3
# audi                     0        0          1      5      1           7
# bmw                      0        0          0      8      0           8
# chevrolet                0        0          2      1      0           3
# dodge                    0        0          5      3      1           9
# honda                    0        0          7      5      1          13
# isuzu                    0        0          1      3      0           4
# jaguar                   0        0          0      3      0           3
# mazda                    0        0         10      7      0          17
# mercedes-benz            1        2          0      4      1           8
# mercury                  0        0          1      0      0           1
# mitsubishi               0        0          9      4      0          13
# ...
